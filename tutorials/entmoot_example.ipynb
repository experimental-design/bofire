# %% [markdown]
# # Demonstration of the Entmoot API
#
# This notebook includes comparisons of the Entmoot strategy to other Bofire
# strategies.

# %% [markdown]
# ## Defining model parameters
#
# Model parameters to be passed into `EntingStrategy` can be defined in a few ways.
# Throughout this notebook, they are defined using a dictionary of parameters.
# However, all of the below are valid.
# The use of `EntingParams` is encouraged, however it does require more imports to use.

# %%
import entmoot.models.model_params as ent_params

# all of these are valid to pass into `EntingStrategy(enting_params=params)`

# as a dictionary
params0 = {"unc_params": {"dist_metric": "l1", "acq_sense": "exploration"}}
# populate EntingParams with dictionary unpacking
params1 = ent_params.EntingParams(**params0)
# use objects directly
params2 = ent_params.EntingParams(
    unc_params=ent_params.UncParams(
        dist_metric="l1",
        acq_sense="exploration"
    )
)
# explictly create all dataclass instances
params3 = ent_params.EntingParams(
    unc_params=ent_params.UncParams(
        dist_metric="l1",
        acq_sense="exploration"
    ),
    tree_train_params=ent_params.TreeTrainParams(
        train_params=ent_params.TrainParams()
    )
)

params1 == params2 == params3
# Out:
# True

# %% [markdown]
# ## Single objective Bayesian Optimization strategy
#
# This section includes a comparison to the Sobo strategy given in the "Getting
# Started" docs. The API is identical, with additional options given to the
# data model. Note that the EntingStrategy only supports one candidate, as
# each generated candidate is optimal (so generating multiple would generate
# duplicates).

# %%
from bofire.benchmarks.single import Himmelblau
import bofire.strategies.mapper as strategy_mapper

benchmark = Himmelblau()

samples = benchmark.domain.inputs.sample(10)
experiments = benchmark.f(samples, return_complete=True)
# Out:
# C:\Users\tobyb\phd\bofire\bofire\surrogates\xgb.py:12: UserWarning: xgboost not installed, BoFire's `XGBoostSurrogate` cannot be used.
#   warnings.warn("xgboost not installed, BoFire's `XGBoostSurrogate` cannot be used.")

# %%
from bofire.data_models.strategies.api import SoboStrategy
from bofire.data_models.acquisition_functions.api import qNEI

sobo_strategy_data_model = SoboStrategy(domain=benchmark.domain, acquisition_function=qNEI())
sobo_strategy = strategy_mapper.map(sobo_strategy_data_model)

sobo_strategy.tell(experiments=experiments)
sobo_strategy.ask(candidate_count=2)
# Out:
#         x_1       x_2      y_pred        y_sd       y_des
# 0  5.028809  0.282956  158.004321  314.289086 -158.004321
# 1 -0.299493  0.858126   75.802201  276.831445  -75.802201

# %%
from bofire.data_models.strategies.api import EntingStrategy

enting_params = {"unc_params": {"dist_metric": "l1", "acq_sense": "exploration"}}
solver_params = {"solver_name": "gurobi"}

enting_strategy_data_model = EntingStrategy(
    domain=benchmark.domain, solver_params=solver_params,
    enting_params=enting_params,                                        
    learn_from_candidates_coeff=10.0
)

enting_strategy = strategy_mapper.map(enting_strategy_data_model)

enting_strategy.tell(experiments=experiments)
enting_strategy.ask(candidate_count=2)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-06
# Read LP format model from file C:\Users\tobyb\AppData\Local\Temp\tmp3me86j93.pyomo.lp
# Reading time = 0.00 seconds
# x1: 1121 rows, 648 columns, 3774 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1121 rows, 648 columns and 3774 nonzeros
# Model fingerprint: 0x0273e6a9
# Variable types: 602 continuous, 46 integer (46 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 4e+02]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [6e-02, 6e+00]
# Presolve removed 151 rows and 92 columns
# Presolve time: 0.00s
# Presolved: 970 rows, 556 columns, 2916 nonzeros
# Variable types: 530 continuous, 26 integer (26 binary)
# Found heuristic solution: objective 193.7483728
# Found heuristic solution: objective 160.9157630
#
# Root relaxation: objective 1.137642e+00, 192 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.13764    0    8  160.91576    1.13764  99.3%     -    0s
# H    0     0                       1.8047505    1.13764  37.0%     -    0s
# H    0     0                       1.5987045    1.13764  28.8%     -    0s
# H    0     0                       1.5144723    1.13764  24.9%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 1
#   Flow cover: 1
#
# Explored 1 nodes (192 simplex iterations) in 0.04 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 1.51447 1.5987 1.80475 ... 193.748
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.514472319793e+00, best bound 1.514472319793e+00, gap 0.0000%
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-06
# Read LP format model from file C:\Users\tobyb\AppData\Local\Temp\tmp3af89sau.pyomo.lp
# Reading time = 0.00 seconds
# x1: 1270 rows, 726 columns, 4298 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1270 rows, 726 columns and 4298 nonzeros
# Model fingerprint: 0xc26cae3c
# Variable types: 676 continuous, 50 integer (50 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 4e+02]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [6e-02, 6e+00]
# Presolve removed 46 rows and 46 columns
# Presolve time: 0.02s
# Presolved: 1224 rows, 680 columns, 3782 nonzeros
# Variable types: 653 continuous, 27 integer (27 binary)
# Found heuristic solution: objective 182.3470894
# Found heuristic solution: objective 173.2249981
#
# Root relaxation: objective 8.834482e-01, 254 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.88345    0    9  173.22500    0.88345  99.5%     -    0s
# H    0     0                       1.3919747    0.88345  36.5%     -    0s
# H    0     0                       1.2466690    0.88345  29.1%     -    0s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 1
#   Flow cover: 2
#   Relax-and-lift: 2
#
# Explored 1 nodes (254 simplex iterations) in 0.04 seconds (0.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 1.24667 1.39197 173.225 182.347
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.246668953035e+00, best bound 1.246668953035e+00, gap 0.0000%
#         x_1       x_2    y_pred      y_sd     y_des
# 0  6.000000 -3.349438  1.807020  0.386341 -1.807020
# 0  5.446058  0.000000  2.165424  0.403288 -2.165424

# %% [markdown]
# When `candidate_count > 1`, the strategy will fit to each candidate in order to produce the next candidate. This means that sequential calls to `EntingStrategy.ask()` will tend to be further from the ground truth.

# %%
enting_strategy.ask(candidate_count=5)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-06
# Read LP format model from file C:\Users\tobyb\AppData\Local\Temp\tmpxyg_225v.pyomo.lp
# Reading time = 0.02 seconds
# x1: 1375 rows, 782 columns, 4705 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1375 rows, 782 columns and 4705 nonzeros
# Model fingerprint: 0xb7bf3842
# Variable types: 728 continuous, 54 integer (54 binary)
# Coefficient statistics:
#   Matrix range     [7e-03, 4e+02]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [6e-02, 6e+00]
# Presolve removed 49 rows and 49 columns
# Presolve time: 0.00s
# Presolved: 1326 rows, 733 columns, 4191 nonzeros
# Variable types: 704 continuous, 29 integer (29 binary)
# Found heuristic solution: objective 165.8761717
# Found heuristic solution: objective 33.9045555
#
# Root relaxation: objective 8.781591e-01, 255 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.87816    0    9   33.90456    0.87816  97.4%     -    0s
# H    0     0                       1.3681591    0.87816  35.8%     -    0s
# H    0     0                       1.3560134    0.87816  35.2%     -    0s
# H    0     0                       1.3550451    0.87816  35.2%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 1
#   Implied bound: 29
#   Clique: 4
#   MIR: 3
#   Flow cover: 1
#   RLT: 1
#   Relax-and-lift: 2
#
# Explored 1 nodes (255 simplex iterations) in 0.05 seconds (0.04 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 1.35505 1.35601 1.36816 ... 165.876
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.355045093934e+00, best bound 1.355045093934e+00, gap 0.0000%
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-06
# Read LP format model from file C:\Users\tobyb\AppData\Local\Temp\tmp7lz4k2bp.pyomo.lp
# Reading time = 0.02 seconds
# x1: 1347 rows, 771 columns, 4584 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1347 rows, 771 columns and 4584 nonzeros
# Model fingerprint: 0xad4bb77b
# Variable types: 712 continuous, 59 integer (59 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 4e+02]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 6e+00]
# Presolve removed 74 rows and 59 columns
# Presolve time: 0.01s
# Presolved: 1273 rows, 712 columns, 3988 nonzeros
# Variable types: 680 continuous, 32 integer (32 binary)
# Found heuristic solution: objective 177.6341575
# Found heuristic solution: objective 107.9464206
# Found heuristic solution: objective 26.7196644
#
# Root relaxation: objective 1.420588e+00, 312 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.42059    0    9   26.71966    1.42059  94.7%     -    0s
# H    0     0                       1.6019106    1.42059  11.3%     -    0s
# H    0     0                       1.5385223    1.42059  7.67%     -    0s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 11
#   Implied bound: 20
#   Clique: 13
#   MIR: 9
#   Flow cover: 8
#   Network: 3
#   RLT: 3
#   Relax-and-lift: 95
#
# Explored 1 nodes (312 simplex iterations) in 0.05 seconds (0.04 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 1.53852 1.60191 26.7197 ... 177.634
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.538522346424e+00, best bound 1.538522346424e+00, gap 0.0000%
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-06
# Read LP format model from file C:\Users\tobyb\AppData\Local\Temp\tmprpzf0vqc.pyomo.lp
# Reading time = 0.00 seconds
# x1: 1443 rows, 822 columns, 4939 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1443 rows, 822 columns and 4939 nonzeros
# Model fingerprint: 0xcb9e15de
# Variable types: 758 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 3e+02]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 6e+00]
# Presolve removed 57 rows and 57 columns
# Presolve time: 0.01s
# Presolved: 1386 rows, 765 columns, 4414 nonzeros
# Variable types: 732 continuous, 33 integer (33 binary)
# Found heuristic solution: objective 9.6288504
#
# Root relaxation: objective 1.547365e+00, 273 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.54736    0   27    9.62885    1.54736  83.9%     -    0s
#      0     0    5.70286    0    8    9.62885    5.70286  40.8%     -    0s
# H    0     0                       5.8468862    5.70286  2.46%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 1
#   Implied bound: 31
#   Clique: 3
#   MIR: 6
#   Flow cover: 2
#   RLT: 2
#   Relax-and-lift: 2
#
# Explored 1 nodes (383 simplex iterations) in 0.04 seconds (0.04 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 5.84689 9.62885
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.846886241140e+00, best bound 5.846886241140e+00, gap 0.0000%
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-06
# Read LP format model from file C:\Users\tobyb\AppData\Local\Temp\tmpe_apaebu.pyomo.lp
# Reading time = 0.01 seconds
# x1: 1423 rows, 815 columns, 4851 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1423 rows, 815 columns and 4851 nonzeros
# Model fingerprint: 0x8514830b
# Variable types: 746 continuous, 69 integer (69 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 3e+02]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 6e+00]
# Presolve removed 73 rows and 62 columns
# Presolve time: 0.01s
# Presolved: 1350 rows, 753 columns, 4277 nonzeros
# Variable types: 717 continuous, 36 integer (36 binary)
# Found heuristic solution: objective 212.1578476
# Found heuristic solution: objective 9.7637305
#
# Root relaxation: objective -2.203099e+01, 345 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -22.03099    0   30    9.76373  -22.03099   326%     -    0s
#      0     0  -21.99253    0   27    9.76373  -21.99253   325%     -    0s
# H    0     0                     -15.3265186  -21.99253  43.5%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 18
#   Implied bound: 236
#   Clique: 24
#   MIR: 28
#   Flow cover: 24
#   RLT: 22
#   Relax-and-lift: 78
#   PSD: 3
#
# Explored 1 nodes (363 simplex iterations) in 0.08 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: -15.3265 9.76373 212.158
# No other solutions better than -15.3265
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.532651860171e+01, best bound -1.532651860171e+01, gap 0.0000%
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-06
# Read LP format model from file C:\Users\tobyb\AppData\Local\Temp\tmp7oek_a3s.pyomo.lp
# Reading time = 0.02 seconds
# x1: 1418 rows, 816 columns, 4807 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1418 rows, 816 columns and 4807 nonzeros
# Model fingerprint: 0xe14fb0ad
# Variable types: 743 continuous, 73 integer (73 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e-02, 6e+00]
# Presolve removed 44 rows and 44 columns
# Presolve time: 0.02s
# Presolved: 1374 rows, 772 columns, 4308 nonzeros
# Variable types: 734 continuous, 38 integer (38 binary)
# Found heuristic solution: objective 7.1166371
# Found heuristic solution: objective -15.9379137
#
# Root relaxation: objective -6.591438e+01, 409 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -65.91438    0   35  -15.93791  -65.91438   314%     -    0s
#      0     0  -43.10180    0   19  -15.93791  -43.10180   170%     -    0s
# H    0     0                     -42.5768652  -43.10180  1.23%     -    0s
# H    0     0                     -42.6533729  -43.10180  1.05%     -    0s
#
# Cutting planes:
#   Gomory: 11
#   Implied bound: 3
#   MIR: 14
#   Flow cover: 3
#   RLT: 3
#
# Explored 1 nodes (544 simplex iterations) in 0.08 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: -42.6534 -42.5769 -15.9379 7.11664
# No other solutions better than -42.6534
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.265337288544e+01, best bound -4.265337288544e+01, gap 0.0000%
#         x_1       x_2      y_pred      y_sd       y_des
# 0  3.643090 -0.160579  212.354874  0.286032 -212.354874
# 0  6.000000  6.000000    1.976358  0.472637   -1.976358
# 0  5.723030 -2.215150    5.962139  0.242492   -5.962139
# 0  5.723030  2.999999  -15.058899  0.369514   15.058899
# 0  3.654947  3.601530  -42.435354  0.333518   42.435354

# %% [markdown]
# ## Multi Objective BO

# %%
from bofire.benchmarks.multi import DTLZ2
import bofire.strategies.mapper as strategy_mapper

benchmark = DTLZ2(dim=2, num_objectives=2)

samples = benchmark.domain.inputs.sample(10)
experiments = benchmark.f(samples, return_complete=True)

# %%
enting_params = {"unc_params": {"dist_metric": "l1", "acq_sense": "exploration"}}
solver_params = {"solver_name": "gurobi"}

enting_strategy_data_model = EntingStrategy(
    domain=benchmark.domain, solver_params=solver_params,
    enting_params=enting_params,                                        
    learn_from_candidates_coeff=10.0
)
enting_strategy = strategy_mapper.map(enting_strategy_data_model)

enting_strategy.tell(experiments=experiments)
enting_strategy.ask(candidate_count=1)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-06
# Read LP format model from file C:\Users\tobyb\AppData\Local\Temp\tmpc3tulzyp.pyomo.lp
# Reading time = 0.01 seconds
# x1: 2536 rows, 1406 columns, 8825 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2536 rows, 1406 columns and 8825 nonzeros
# Model fingerprint: 0x40eeaac1
# Variable types: 1360 continuous, 46 integer (46 binary)
# Coefficient statistics:
#   Matrix range     [7e-08, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-02, 1e+00]
# Presolve removed 194 rows and 109 columns
# Presolve time: 0.02s
# Presolved: 2342 rows, 1297 columns, 8641 nonzeros
# Variable types: 1271 continuous, 26 integer (26 binary)
# Found heuristic solution: objective 0.1400170
# Found heuristic solution: objective -0.1540739
#
# Root relaxation: objective -8.415270e-01, 1566 iterations, 0.05 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.84153    0   20   -0.15407   -0.84153   446%     -    0s
# H    0     0                      -0.3187198   -0.84153   164%     -    0s
# H    0     0                      -0.3818343   -0.84153   120%     -    0s
#      0     0   -0.38183    0   21   -0.38183   -0.38183  0.00%     -    0s
#
# Cutting planes:
#   Cover: 9
#   Implied bound: 252
#   Clique: 8
#   MIR: 72
#   Flow cover: 7
#   Network: 1
#   RLT: 17
#   Relax-and-lift: 164
#   BQP: 1
#   PSD: 6
#
# Explored 1 nodes (2294 simplex iterations) in 0.34 seconds (0.44 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: -0.381834 -0.31872 -0.154074 0.140017
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.818343342505e-01, best bound -3.818343342505e-01, gap 0.0000%
#    x_0  x_1  f_0_pred  f_1_pred    f_0_sd    f_1_sd   f_0_des   f_1_des
# 0  1.0  0.0  0.239611  0.999267  0.491768  0.491768 -0.239611 -0.999267

# %% [markdown]
# ## Maximize single objective

# %%
from bofire.benchmarks.single import Ackley

benchmark = Ackley()

samples = benchmark.domain.inputs.sample(10)
experiments = benchmark.f(samples, return_complete=True)

# %%
enting_params = {"unc_params": {"dist_metric": "l1", "acq_sense": "exploration"}}
solver_params = {"solver_name": "gurobi"}

enting_strategy_data_model = EntingStrategy(
    domain=benchmark.domain, solver_params=solver_params,
    enting_params=enting_params,                                        
    learn_from_candidates_coeff=10.0
)
enting_strategy = strategy_mapper.map(enting_strategy_data_model)

enting_strategy.tell(experiments=experiments)
enting_strategy.ask(candidate_count=1)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-06
# Read LP format model from file C:\Users\tobyb\AppData\Local\Temp\tmpoq8unk2t.pyomo.lp
# Reading time = 0.01 seconds
# x1: 1085 rows, 630 columns, 3596 nonzeros
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1085 rows, 630 columns and 3596 nonzeros
# Model fingerprint: 0x639898d2
# Variable types: 584 continuous, 46 integer (46 binary)
# Coefficient statistics:
#   Matrix range     [1e-07, 6e+01]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [2e-02, 3e+01]
# Presolve removed 75 rows and 49 columns
# Presolve time: 0.00s
# Presolved: 1010 rows, 581 columns, 2992 nonzeros
# Variable types: 555 continuous, 26 integer (26 binary)
# Found heuristic solution: objective -17.9471755
# Found heuristic solution: objective -18.3201447
#
# Root relaxation: objective -2.084561e+01, 465 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -20.84561    0   25  -18.32014  -20.84561  13.8%     -    0s
# H    0     0                     -19.9804953  -20.84561  4.33%     -    0s
# H    0     0                     -20.1597841  -20.84561  3.40%     -    0s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 13
#   Cover: 14
#   Implied bound: 164
#   Clique: 14
#   MIR: 8
#   Flow cover: 9
#   RLT: 38
#   Relax-and-lift: 19
#   PSD: 18
#
# Explored 1 nodes (480 simplex iterations) in 0.10 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: -20.1598 -19.9805 -18.3201 -17.9472
# No other solutions better than -20.1598
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.015978412475e+01, best bound -2.015978412475e+01, gap 0.0000%
#       x_1        x_2     y_pred      y_sd      y_des
# 0 -32.768 -27.639076  19.890957  0.370347  19.890957

# %% [markdown]
# ## Compare domain to problem config
#
# BoFire defines its problems using Domains, whereas ENTMOOT uses ProblemConfigs.
# This demonstrates the conversion from Domain to ProblemConfig, using the multi
# objective categorical problem defined in the ENTMOOT benchmark.

# %%
from bofire.data_models.domain.api import Domain, Inputs, Outputs
from bofire.data_models.features.api import (
    CategoricalInput,
    ContinuousInput,
    DiscreteInput,
    ContinuousOutput,
)
from bofire.data_models.objectives.api import MinimizeObjective


def build_multi_obj_categorical_problem(n_obj: int = 2, no_cat=False) -> Domain:
    """
    Builds a small test example which is used in Entmoot tests.
    """

    cat_feat = (
        []
        if no_cat
        else [CategoricalInput(key="x0", categories=("blue", "orange", "gray"))]
    )
    input_features = Inputs(
        features=cat_feat
        + [
            DiscreteInput(key="x1", values=[5, 6]),
            DiscreteInput(key="x2", values=[0, 1]),  # binary
            ContinuousInput(key="x3", bounds=[5.0, 6.0]),
            ContinuousInput(key="x4", bounds=[4.6, 6.0]),
            ContinuousInput(key="x5", bounds=[5.0, 6.0]),
        ]
    )

    output_features = Outputs(
        features=[
            ContinuousOutput(
                key=f"y{i}", objective=MinimizeObjective(w=1.0, bounds=[0.0, 1.0])
            )
            for i in range(n_obj)
        ]
    )

    domain = Domain(inputs=input_features, outputs=output_features)

    return domain

# %%
from bofire.utils.entmoot import domain_to_problem_config
import entmoot.benchmarks as ent
from entmoot.problem_config import ProblemConfig

domain = build_multi_obj_categorical_problem()
problem_config, _ = domain_to_problem_config(domain)
problem_config_ent = ProblemConfig()
ent.build_multi_obj_categorical_problem(problem_config_ent)

print(problem_config, "\n", problem_config_ent)
# Out:
# PROBLEM SUMMARY
# ---------------
# features:
# x0 :: Categorical :: ('blue', 'orange', 'gray')
# x1 :: Integer :: (5, 6)
# x2 :: Binary :: (0, 1)
# x3 :: Real :: (5.0, 6.0)
# x4 :: Real :: (4.6, 6.0)
# x5 :: Real :: (5.0, 6.0)
#
# objectives:
# y0 :: MinObjective
# y1 :: MinObjective
#
# PROBLEM SUMMARY
# ---------------
# features:
# feat_0 :: Categorical :: ('blue', 'orange', 'gray')
# feat_1 :: Integer :: (5, 6)
# feat_2 :: Binary :: (0, 1)
# feat_3 :: Real :: (5.0, 6.0)
# feat_4 :: Real :: (4.6, 6.0)
# feat_5 :: Real :: (5.0, 6.0)
#
# objectives:
# obj_0 :: MinObjective
# obj_1 :: MinObjective
